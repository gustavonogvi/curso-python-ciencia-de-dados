# %% [markdown]
# # Lista de Exercícios — Módulo 2
#
# **Curso:** Python para Ciência de Dados
# **Disciplina:** Ciência de Dados (T326) — UNIFOR
#
# Resolva cada exercício na célula indicada. O gabarito está no arquivo `gabarito_modulo2.ipynb`.

# %% [markdown]
# Execute a célula abaixo antes de começar — ela cria o DataFrame base usado nos exercícios.

# %%
import pandas as pd

dados = {
    "nome": ["Ana", "Bruno", "Carlos", "Daniela"],
    "idade": [23, 35, 29, 41],
    "nota": [8.5, 6.0, 7.5, 9.0]
}

df = pd.DataFrame(dados)
df

# %% [markdown]
# ---
# ### Exercício 1 — Seleção de Dados
#
# 1. Exiba apenas a coluna `nome`
# 2. Exiba as colunas `nome` e `nota`

# %%
# Exercício 1

# %% [markdown]
# ---
# ### Exercício 2 — Filtro
#
# 1. Mostre apenas os alunos com nota maior que 7
# 2. Mostre apenas as pessoas com idade maior que 30

# %%
# Exercício 2

# %% [markdown]
# ---
# ### Exercício 3 — Nova Coluna
#
# Crie uma coluna chamada `status`:
# - `"Aprovado"` se nota >= 7
# - `"Reprovado"` caso contrário

# %%
# Exercício 3

# %% [markdown]
# ---
# ### Exercício 4 — Ordenação
#
# Ordene o DataFrame:
# 1. Pela coluna `idade` (crescente)
# 2. Pela coluna `nota` (decrescente)

# %%
# Exercício 4

# %% [markdown]
# ---
# ### Exercício 5 — Estatísticas
#
# Calcule:
# 1. Média das idades
# 2. Maior nota
# 3. Menor nota

# %%
# Exercício 5

# %% [markdown]
# ---
# ### Exercício 6 — Limpeza de Dados
#
# Dado o DataFrame abaixo:
# 1. Verifique os valores nulos
# 2. Preencha os nulos da coluna `nota` com a média
# 3. Remova as linhas duplicadas

# %%
import pandas as pd

dados_sujos = {
    "nome": ["Ana", "Bruno", "Carlos", "Ana"],
    "idade": [23, None, 29, 23],
    "nota": [8.5, 7.0, None, 8.5]
}

df_sujo = pd.DataFrame(dados_sujos)

# Resolva aqui
